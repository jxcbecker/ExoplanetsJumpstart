# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
obl_data_raw = pd.read_csv("/Users/jcbecker/Downloads/obliquity (3).csv", skiprows = [1,2])
obl_data = obl_data_raw.loc[obl_data_raw['Pflag'] == 'y']

# %%
ipac_data_raw = pd.read_csv("PS_2025.03.05_11.27.17.csv", skiprows = 100)
ipac_data = ipac_data_raw.loc[(ipac_data_raw['discoverymethod'] == 'Transit')]

# %%
# this is just to combine the data from the two sources - people don't use the same names in each...

def normalize_name(name: str) -> str:
    return (name.strip()       
            .lower()             
            .replace('_', '')
            .replace('-0', '') 
            .replace('-', '') 
            .replace(' ', ''))

obl_data['merge_key'] = obl_data['System'].apply(normalize_name)
ipac_data['merge_key'] = ipac_data['pl_name'].apply(normalize_name)
obl_data['merge_key2'] = obl_data['System'].apply(normalize_name)
ipac_data['merge_key2'] = ipac_data['hostname'].apply(normalize_name)

merged_df1 = pd.merge(obl_data, ipac_data, on='merge_key', how='inner')
merged_df2 = pd.merge(obl_data, ipac_data, on='merge_key2', how='inner')
final_merged_df = pd.concat([merged_df1, merged_df2], axis=0, ignore_index=True)

#check for failures
unmatched_rows = obl_data[~obl_data['System'].isin(final_merged_df['System'])]
# Out:
# /Users/jcbecker/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/jcbecker/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/jcbecker/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# ...

# %%
final_merged_df.columns
# Out:
# Index(['Author_string', 'Ephemeris_reference', 'Pflag', 'System', 'Teff',
#        'dec', 'decstr', 'default_flag', 'disc_facility', 'disc_year',
#        ...
#        'sy_kmag', 'sy_kmagerr1', 'sy_kmagerr2', 'sy_pnum', 'sy_refname',
#        'sy_snum', 'sy_vmag', 'sy_vmagerr1', 'sy_vmagerr2', 'ttv_flag'],
#       dtype='object', length=111)

# %%
#exclusions
idx = (final_merged_df['lambda'] != -999) 

#plot it
plt.errorbar(final_merged_df.loc[idx]['Teff'], final_merged_df.loc[idx]['lambda'], 
             yerr = [final_merged_df.loc[idx]['errdn'], final_merged_df.loc[idx]['errup']], linestyle='None', marker = 'o')
plt.ylabel("Obliquity (deg)", fontsize = 15)
plt.xlabel("T$_{eff}$ (K)", fontsize = 15)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.axvline(6250, c='r', linestyle="--")

# %% [markdown]
# ## Choose your own x axis

# %%
#exclusions
plt.figure(figsize = (14, 3))
idx = (final_merged_df['lambda'] > -900) 
idx1 = idx & (final_merged_df['sy_pnum']<=1) 
#plot it
plt.errorbar(final_merged_df.loc[idx1]['Teff'], final_merged_df.loc[idx1]['lambda'], 
             yerr = [final_merged_df.loc[idx1]['errdn'], final_merged_df.loc[idx1]['errup']], linestyle='None', alpha = 0.5, marker = 'o', label="Single Planet")
idx2 = (final_merged_df['sy_pnum'] >1) & idx

plt.errorbar(final_merged_df.loc[idx2]['Teff'], final_merged_df.loc[idx2]['lambda'], 
             yerr = [final_merged_df.loc[idx2]['errdn'], final_merged_df.loc[idx2]['errup']], color = "DarkRed", linestyle='None', marker = 's', label="Multi-planet")

plt.ylabel("Obliquity (deg)", fontsize = 15)
plt.xlabel("T$_{eff}$ (K)", fontsize = 15)
plt.ylim(-180, 180)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.legend()

# %%
#how man have multiple planets? 
idx = (final_merged_df['sy_pnum'] > 1)
print(len(final_merged_df.loc[idx]['hostname'].unique()), final_merged_df.loc[idx]['hostname'].unique())
# Out:
# 32 ['AU Mic' 'HD 106315' 'K2-290' 'Kepler-25' 'TOI-942' 'TRAPPIST-1'
#  'V1298 Tau' 'WASP-47' 'HAT-P-2' 'HAT-P-11' 'HAT-P-13' 'HAT-P-17'
#  'HD 110067' 'HD 191939' 'HIP 67522' 'KELT-6' 'Kepler-30' 'Kepler-1656'
#  'TOI-1130' 'TOI-1136' 'TOI-1670' 'TOI-1694' 'TOI-2076' 'TOI-2202'
#  'TOI-5126' 'TOI-5398' 'WASP-18' 'WASP-41' 'WASP-53' 'WASP-84' 'WASP-107'
#  'WASP-148']

# %%
#how many are small?
idx = (final_merged_df['pl_rade'] < 4) & (final_merged_df['sy_pnum'] > 0)
len(final_merged_df.loc[idx]['hostname'].unique())
# Out:
# 17

# %%
# Out:
# 17

# %%
threshold = 6250
hot_stars = final_merged_df.loc[(final_merged_df['Teff'] > threshold) & (final_merged_df['lambda'] != -999)]
cool_stars = final_merged_df.loc[(final_merged_df['Teff'] <= threshold) & (final_merged_df['lambda'] != -999)]

plt.figure(figsize=(8,5))
plt.hist(cool_stars['lambda'], bins=20, alpha=0.7, density = True, label=r'Cool stars (Teff <= 6250 K)')
plt.hist(hot_stars['lambda'], bins=20, alpha=0.7, density = True, label="Hot stars (Teff > 6250 K)")

plt.xlabel("Obliquity (deg)", fontsize=15)
plt.ylabel("Number of systems", fontsize=15)
plt.legend(fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# Out:
# (array([0.   , 0.005, 0.01 , 0.015, 0.02 , 0.025]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
from scipy.stats import ks_2samp

hot_vals = hot_stars['lambda'].values
cool_vals = cool_stars['lambda'].values
ks_stat, p_value = ks_2samp(hot_vals, cool_vals) # this doesn't work if you haven't normalized distributions in the same way. it doesn't know 360 deg = 0 deg

print(p_value)
# Out:
# 0.007058218113325854
